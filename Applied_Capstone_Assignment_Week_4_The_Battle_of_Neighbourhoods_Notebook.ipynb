# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit311/Coursera_Capstone/blob/main/Applied_Capstone_Assignment_Week_4_The_Battle_of_Neighbourhoods_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Where to go London or New York, where I will get good Indian food ?***

# %% [markdown]
# # **Introduction**

# %% [markdown]
# London and New York are the cities where people find lots of different variety of food to eat. These two cities are quite popular tourist and vacation destinations for people all around the world. They are diverse and multicultural and offer a wide variety of experiences that is widely sought after. Indian people who already live there or tourist from India who visit these cities are in search of good authentic Indian food. A lot has changed over the years and we now take a look at how these two cities hotels and restuarant have grown in term of bringing new Indian food to there menu.
#
# In this project lets try to help those people and find there perfect place to eat and enjoy there time by having perfect Indian food cities has to offer.

# %% [markdown]
# # **Business Problem**

# %% [markdown]
# The aim is to help tourist from India who visit London and New York and Indian People who already stays there find suitable hotels and restaurant who serve good and authentic Indian food to them. This will also help people make decisions if they are thinking about vacation in these beautiful cities.

# %% [markdown]
# # **Data Description**

# %% [markdown]
# We require geographical location data for both London and New York.
#
# **London**
#
# To derive our solution, We scrape our data from [link](https://en.wikipedia.org/wiki/List_of_areas_of_London).
#
# This wikipedia page has information about all the neighbourhoods, we limit it London.
#
# Data Column Details -
# *   borough : Name of borough
# *   town : Name of town
#
# This wikipedia page lacks information about the London geographical locations. To solve this problem we will use a python libary [geopy](https://pypi.org/project/geopy/).
#
# **New York**
#
# To derive our solution, We scrape our data from [link](https://en.wikipedia.org/wiki/New_York_City).
#
# This wikipedia page has information about all the boroughs of New York City.
#
# Data Column Details -
#
# *   borough : Name of borough
# *   town : Name of town
#
# This wikipedia page lacks information about the New York City geographical locations. To solve this problem we will use a python libary [geopy](https://pypi.org/project/geopy/).
#
# **Foursquare API Data**
#
# We will need data about different hotels ans restaurants in different neighbourhoods of that specific borough. In order to gain that information we will use "Foursquare" locational information. Foursquare is a location data provider with information about all manner of venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. As such, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
# The data retrieved from Foursquare contained information of venues within a specified distance of the longitude and latitude of the postcodes. Based on all the information collected for both London and New York City, we have sufficient data to build our model. We then present our observations and findings. Using this data, our stakeholders can take the necessary decision.

# %% [markdown]
# # **Methodology**

# %% [markdown]
# We will be creating our model with the help of Python so we start off by importing all the required python packages.

# %%
# importing library
import pandas as pd
import numpy as np
import requests
# for data extraction
from bs4 import BeautifulSoup
# for plotting map
import folium
# for clusterring using KMeans algorithm
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
from geopy.geocoders import Nominatim
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %% [markdown]
# The approach taken here is to explore each of the cities individually, plot the map to show the neighbourhoods being considered and then build our model by clustering all of the similar neighbourhoods together and finally plot the new map with the clustered neighbourhoods. We draw insights and then compare and discuss our findings.

# %% [markdown]
# # **Exploring London**

# %% [markdown]
# **Neighbourhoods of London**
#
# We begin to start collecting and refining the data needed for the our business solution to work.
#
# **Data Collection**
#
# To get the neighbourhoods in London, we start by scraping the list of areas of London wiki page.

# %%
# reading data from wiki page
london_data_url = "https://en.wikipedia.org/wiki/List_of_areas_of_London"
response = requests.get(london_data_url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Response 200 means that we are able to make the connection

# %%
# using Beautiful soup library to parse HTML data
soup_obj = BeautifulSoup(response.text, 'xml')
table_obj=soup_obj.findAll('table')
london_data_table = table_obj[1]

# %%
# parsing table data row and column wise
table_contents=[]
for row in london_data_table.findAll('tr'):
    cell = {}
    col_number = 0
    for col in row.findAll('td'):
        cell['col_'+str(col_number)] = str.strip(col.text)
        col_number += 1
    if len(cell) > 0:
        table_contents.append(cell)

# %%
# creating dataframe
london_data_df=pd.DataFrame(table_contents)
london_data_df.head(10)
# Out:
#               col_0                              col_1  ... col_4     col_5
# 0        Abbey Wood             Bexley,  Greenwich [7]  ...   020  TQ465785
# 1             Acton  Ealing, Hammersmith and Fulham[8]  ...   020  TQ205805
# 2         Addington                         Croydon[8]  ...   020  TQ375645
# 3        Addiscombe                         Croydon[8]  ...   020  TQ345665
# 4       Albany Park                             Bexley  ...   020  TQ478728
# 5  Aldborough Hatch                       Redbridge[9]  ...   020  TQ455895
# 6           Aldgate                           City[10]  ...   020  TQ334813
# 7           Aldwych                    Westminster[10]  ...   020  TQ307810
# 8          Alperton                          Brent[11]  ...   020  TQ185835
# 9           Anerley                        Bromley[11]  ...   020  TQ345695
#
# [10 rows x 6 columns]

# %%
# renaming columns of dataframe
london_data_df.columns = ['location', 'london_borough', 'post_town', 'postcode', 'dial_code', 'os_grid_ref']
london_data_df.head(5)
# Out:
#       location                     london_borough  ... dial_code os_grid_ref
# 0   Abbey Wood             Bexley,  Greenwich [7]  ...       020    TQ465785
# 1        Acton  Ealing, Hammersmith and Fulham[8]  ...       020    TQ205805
# 2    Addington                         Croydon[8]  ...       020    TQ375645
# 3   Addiscombe                         Croydon[8]  ...       020    TQ345665
# 4  Albany Park                             Bexley  ...       020    TQ478728
#
# [5 rows x 6 columns]

# %% [markdown]
# **Feature Selection**
#
# We need only the london_borough, postal_town, post_code for further steps. We can drop the location, dial_code and os_grid_ref.

# %%
london_data_df = london_data_df.drop(['location', 'dial_code', 'os_grid_ref'], axis = 1)
london_data_df.head(10)
# Out:
#                       london_borough       post_town   postcode
# 0             Bexley,  Greenwich [7]          LONDON        SE2
# 1  Ealing, Hammersmith and Fulham[8]          LONDON     W3, W4
# 2                         Croydon[8]         CROYDON        CR0
# 3                         Croydon[8]         CROYDON        CR0
# 4                             Bexley  BEXLEY, SIDCUP  DA5, DA14
# 5                       Redbridge[9]          ILFORD        IG2
# 6                           City[10]          LONDON        EC3
# 7                    Westminster[10]          LONDON        WC2
# 8                          Brent[11]         WEMBLEY        HA0
# 9                        Bromley[11]          LONDON       SE20

# %% [markdown]
# Let's remove the Square brackets [ ] and numbers from the london_borough column

# %%
london_data_df['london_borough'] = london_data_df['london_borough'].map(lambda x: x.rstrip(']').rstrip('0123456789').rstrip('['))
london_data_df.head(10)
# Out:
#                    london_borough       post_town   postcode
# 0             Bexley,  Greenwich           LONDON        SE2
# 1  Ealing, Hammersmith and Fulham          LONDON     W3, W4
# 2                         Croydon         CROYDON        CR0
# 3                         Croydon         CROYDON        CR0
# 4                          Bexley  BEXLEY, SIDCUP  DA5, DA14
# 5                       Redbridge          ILFORD        IG2
# 6                            City          LONDON        EC3
# 7                     Westminster          LONDON        WC2
# 8                           Brent         WEMBLEY        HA0
# 9                         Bromley          LONDON       SE20

# %% [markdown]
# Take the dimension of the dataframe

# %%
london_data_df.shape
# Out:
# (531, 3)

# %% [markdown]
# We currently have 531 records and 3 columns of our data. It's time to perform Feature Engineering

# %% [markdown]
# **Feature Engineering**
#
# We can only focusing on the neighbourhoods of London, so performing the changes

# %%
london_data_df = london_data_df[london_data_df['post_town'].str.contains('LONDON')]
london_data_df.head(10)
# Out:
#                     london_borough       post_town  postcode
# 0              Bexley,  Greenwich           LONDON       SE2
# 1   Ealing, Hammersmith and Fulham          LONDON    W3, W4
# 6                             City          LONDON       EC3
# 7                      Westminster          LONDON       WC2
# 9                          Bromley          LONDON      SE20
# 10                       Islington          LONDON   EC1, N1
# 12                       Islington          LONDON       N19
# 14                          Barnet  BARNET, LONDON  EN5, NW7
# 15                         Enfield          LONDON  N11, N14
# 16                      Wandsworth          LONDON      SW12

# %%
london_data_df.shape
# Out:
# (308, 3)

# %% [markdown]
# let's drop the duplicates row, dropping to enhance performance

# %%
london_data_df = london_data_df.drop_duplicates()

# %%
london_data_df.shape
# Out:
# (193, 3)

# %% [markdown]
# We now have only 193 rows. We can proceed with our further steps. Getting some descriptive statistics

# %%
london_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 522
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   london_borough  193 non-null    object
#  1   post_town       193 non-null    object
#  2   postcode        193 non-null    object
# dtypes: object(3)
# memory usage: 6.0+ KB

# %% [markdown]
# let's start by converting the address to its latitude and longitude coordinates.
#
# **Method name** - get_lat_long
#
# **Purpose** - It convert string address into geographical coordinates.
#
# **Input** - Address (string)
#
# **Output** - latitude and longitude coordinates

# %%
def get_lat_long(row):
    address = row[0] + ', ' + row[1]
    try:
        geolocator = Nominatim(user_agent="foursquare_agent")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
    except:
        latitude = 0.0
        longitude = 0.0
    row['latitude'] = latitude
    row['longitude'] = longitude
    return row

# %%
# above method is applied on london borough dataframe
london_data_df = london_data_df.apply(get_lat_long, axis=1)
index_names = london_data_df[ london_data_df['latitude'] == 0.0 ].index
london_data_df.drop(index_names, inplace = True)
london_data_df.head(100)
# Out:
#                      london_borough post_town  ...   latitude  longitude
# 0               Bexley,  Greenwich     LONDON  ...  51.451053   0.079100
# 1    Ealing, Hammersmith and Fulham    LONDON  ...  51.491537  -0.214971
# 6                              City    LONDON  ...  51.515618  -0.091998
# 7                       Westminster    LONDON  ...  51.500444  -0.126540
# 9                           Bromley    LONDON  ...  51.402805   0.014814
# ..                              ...       ...  ...        ...        ...
# 214                          Ealing    LONDON  ...  51.512655  -0.305195
# 223                        Haringey    LONDON  ...  51.601474  -0.111782
# 234                         Lambeth    LONDON  ...  51.501301  -0.117287
# 237                       Islington    LONDON  ...  51.538429  -0.099905
# 238                          Camden    LONDON  ...  51.542305  -0.139560
#
# [100 rows x 5 columns]

# %% [markdown]
# # **Exploring New York**
#
# **Neighbourhoods of New York**
#
# We begin to start collecting and refining the data needed for the our business solution to work.
#
# **Data Collection**
#
# To get the neighbourhoods in New York, we start by scraping the list of areas of New York City wiki page.

# %%
#reading data from wiki page
nyc_data_url = "https://en.wikipedia.org/wiki/New_York_City"
response = requests.get(nyc_data_url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Response 200 means that we are able to make the connection

# %%
# using Beautiful soup library to parse HTML data
soup_obj = BeautifulSoup(response.text, 'xml')
table_obj=soup_obj.findAll('table')
nyc_data_table = table_obj[2]

# %%
# parsing table data row and column wise
table_contents=[]
for row in nyc_data_table.findAll('tr'):
    cell = {}
    col_number = 0
    for col in row.findAll('td'):
        cell['col_'+str(col_number)] = str.strip(col.text)
        col_number += 1
    if len(cell) > 0:
        table_contents.append(cell)

# %%
# creating dataframe
nyc_data_df=pd.DataFrame(table_contents)
nyc_data_df.head(10)
# Out:
#                                                col_0  ...   col_7
# 0                                          The Bronx  ...  13,006
# 1                                           Brooklyn  ...  13,957
# 2                                          Manhattan  ...  27,544
# 3                                             Queens  ...   8,018
# 4                                      Staten Island  ...   3,150
# 5                                   City of New York  ...     NaN
# 6                                  State of New York  ...     NaN
# 7  Sources:[163][164][165] and see individual bor...  ...     NaN
#
# [8 rows x 8 columns]

# %% [markdown]
# **Feature Selection**
#
# We need only the borough name therefore dropping rest of the column.

# %%
nyc_data_df = nyc_data_df.drop(['col_'+str(x) for x in range(1,8)], axis = 1)
nyc_data_df.head(10)
# Out:
#                                                col_0
# 0                                          The Bronx
# 1                                           Brooklyn
# 2                                          Manhattan
# 3                                             Queens
# 4                                      Staten Island
# 5                                   City of New York
# 6                                  State of New York
# 7  Sources:[163][164][165] and see individual bor...

# %%
# renaming columns of dataframe
nyc_data_df.columns = ['nyc_borough']
nyc_data_df.head(10)
# Out:
#                                          nyc_borough
# 0                                          The Bronx
# 1                                           Brooklyn
# 2                                          Manhattan
# 3                                             Queens
# 4                                      Staten Island
# 5                                   City of New York
# 6                                  State of New York
# 7  Sources:[163][164][165] and see individual bor...

# %%
nyc_data_df['post_town'] = 'New York'
nyc_data_df = nyc_data_df[:][:5]
nyc_data_df.head(10)
# Out:
#      nyc_borough post_town
# 0      The Bronx  New York
# 1       Brooklyn  New York
# 2      Manhattan  New York
# 3         Queens  New York
# 4  Staten Island  New York

# %% [markdown]
# Take the dimension of the dataframe

# %%
nyc_data_df.shape
# Out:
# (5, 2)

# %% [markdown]
# We now have only 5 rows. We can proceed with our further steps. Getting some descriptive statistics

# %%
nyc_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nyc_borough  5 non-null      object
#  1   post_town    5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes

# %% [markdown]
# let's start by converting the address to its latitude and longitude coordinates.

# %%
nyc_data_df = nyc_data_df.apply(get_lat_long, axis=1)
nyc_data_df.head(100)
# Out:
#      nyc_borough post_town   latitude  longitude
# 0      The Bronx  New York  40.846651 -73.878594
# 1       Brooklyn  New York  40.650104 -73.949582
# 2      Manhattan  New York  40.789624 -73.959894
# 3         Queens  New York  40.749824 -73.797634
# 4  Staten Island  New York  40.583456 -74.149605

# %% [markdown]
# **Co-ordinates for London**
#
# Getting the geocode for London to help visualize it on the map

# %%
def get_location(address):
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print(f'Latitude - {latitude}, Longitude - {longitude}')
    return [latitude, longitude]

# %% [markdown]
# **Visualize the Map of London**
#
# To help visualize the Map of London and the neighbourhoods in London, we make use of the folium package.

# %%
# visualizing all the neighborhoods of London from the above data frame using folium
# london map
map_london = folium.Map(location=get_location('London, England'),zoom_start=10)

# adding marker to map
for lat,lng,borough,neighbourhood in zip(london_data_df['latitude'],london_data_df['longitude'],london_data_df['london_borough'],london_data_df['post_town']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_london)
map_london
# Out:
# Latitude - 51.5073219, Longitude - -0.1276474
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_3388e7e0d68b4bb8bb382be64b32492a%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3388e7e0d68b4bb8bb382be64b32492a%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_3388e7e0d68b4bb8bb382be64b32492a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_3388e7e0d68b4bb8bb382be64b32492a%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_ed4119b9c10941999e094e86bb35e747%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# **Visualize the Map of New York**
#
# To help visualize the Map of New York and the neighbourhoods in New York, we make use of the folium package.

# %%
# visualizing all the New York neighborhoods from the above data frame using folium
# New York map
map_nyc = folium.Map(location=get_location('New York, USA'),zoom_start=10)

# adding marker to map
for lat,lng,borough,neighbourhood in zip(nyc_data_df['latitude'],nyc_data_df['longitude'],nyc_data_df['nyc_borough'],nyc_data_df['post_town']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_nyc)
map_nyc
# Out:
# Latitude - 40.7127281, Longitude - -74.0060152
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_25cea00cbd8a468f97a9dde3c162dc3a%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_25cea00cbd8a468f97a9dde3c162dc3a%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_25cea00cbd8a468f97a9dde3c162dc3a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_25cea00cbd8a468f97a9dde3c162dc3a%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_10cdcd845fe14b14aaa30bf42d800259%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# let's now use Foursquare API to get Indian restaurant details for both London and New York.

# %% [markdown]
# **Foursquare API Credential**

# %%
# foursquare api credential
CLIENT_ID = 'QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY' # Foursquare ID
CLIENT_SECRET = 'QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21' # Foursquare Secret
ACCESS_TOKEN = '2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2' # FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY
# CLIENT_SECRET:QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21

# %% [markdown]
# Method name - api_request
#
# Purpose - send request to URL
#
# Input - URL (string)
#
# Response - JSON output

# %%
def api_request(url):
    response = requests.get(url).json()
    return response

# %% [markdown]
# ## Search API URL for a specific venue category
#
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# let's find Indian food restaurant in London and its borough through Foursquare API
#
# **Method name** - get_restaurant_london
#
# **Purpose** - It helps in listing all the Indian restaurant in London
#
# **Input** - Dataframe which contain latitude and longitude details, query, radius, client_id, client_secret, access_token, version, limit
#
# **Response** - Restaurant details in JSON format

# %%
def get_restaurant_london(row, query, radius, client_id, client_secret, access_token, version, limit):
    latitude = row[3]
    longitude = row[4]
    url = f'https://api.foursquare.com/v2/venues/search?client_id={client_id}&client_secret={client_secret}&ll={latitude},{longitude}&oauth_token={access_token}&v={version}&query={query}&radius={radius}&limit={limit}'
    print(f'Final URL - {url}')
    resp = api_request(url)
    if resp['meta']['code'] == 200:
        print(resp['response'])
        # assign relevant part of JSON to venues
        venues = resp['response']['venues']
        return venues
    else:
        print(resp)

search_query = 'Indian'
radius = 500
print(f'query - {search_query}')
#london_data_df = london_data_df[:5][:]
london_restaurant_series = london_data_df.apply(get_restaurant_london, args=(search_query, radius, CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN, VERSION, LIMIT), axis=1)
london_restaurant_series_updated = []
for x in london_restaurant_series:
    if len(x) > 0:
        london_restaurant_series_updated.extend(x)
london_restaurant_df = json_normalize(london_restaurant_series_updated)
# Out:
# query - Indian
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4510531,0.0790997&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.49153695,-0.21497089652160112&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '51cf30bf498e2c23fed00261', 'name': 'Indian Express', 'location': {'address': '3 North End Parade', 'lat': 51.49302784342529, 'lng': -0.20823223710944824, 'labeledLatLngs': [{'label': 'display', 'lat': 51.49302784342529, 'lng': -0.20823223710944824}], 'distance': 495, 'postalCode': 'W14 0SJ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['3 North End Parade', 'London', 'Greater London', 'W14 0SJ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732779', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5156177,-0.0919983&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5004439,-0.1265398&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5b7aa96cf96b2c002c2aab72', 'name': 'Indian Street Food', 'location': {'lat': 51.49734481108781, 'lng': -0.13384871301835802, 'labeledLatLngs': [{'label': 'display', 'lat': 51.49734481108781, 'lng': -0.13384871301835802}], 'distance': 612, 'postalCode': 'SW1P 2HZ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['London', 'Greater London', 'SW1P 2HZ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732779', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4028046,0.0148142&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5384287,-0.0999051&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5384287,-0.0999051&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6482779,-0.1726236&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4ce83bacf3bda1437526b8e4', 'name': 'Blue Ginger', 'location': {'address': '7 E Barnet Rd', 'lat': 51.65202147816886, 'lng': -0.17550279660016452, 'labeledLatLngs': [{'label': 'display', 'lat': 51.65202147816886, 'lng': -0.17550279660016452}], 'distance': 461, 'postalCode': 'EN 4 8', 'cc': 'GB', 'city': 'Hertfordshire', 'state': 'Hertfordshire', 'country': 'United Kingdom', 'formattedAddress': ['7 E Barnet Rd', 'Hertfordshire', 'EN 4 8', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732780', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6520851,-0.0810175&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4570271,-0.1932607&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5029222,-0.103458&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5156177,-0.0919983&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4405529,-0.3076394377337949&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6482779,-0.1726236&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4ce83bacf3bda1437526b8e4', 'name': 'Blue Ginger', 'location': {'address': '7 E Barnet Rd', 'lat': 51.65202147816886, 'lng': -0.17550279660016452, 'labeledLatLngs': [{'label': 'display', 'lat': 51.65202147816886, 'lng': -0.17550279660016452}], 'distance': 461, 'postalCode': 'EN 4 8', 'cc': 'GB', 'city': 'Hertfordshire', 'state': 'Hertfordshire', 'country': 'United Kingdom', 'formattedAddress': ['7 E Barnet Rd', 'Hertfordshire', 'EN 4 8', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732780', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5384287,-0.0999051&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4570271,-0.1932607&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5004439,-0.1265398&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5b7aa96cf96b2c002c2aab72', 'name': 'Indian Street Food', 'location': {'lat': 51.49734481108781, 'lng': -0.13384871301835802, 'labeledLatLngs': [{'label': 'display', 'lat': 51.49734481108781, 'lng': -0.13384871301835802}], 'distance': 612, 'postalCode': 'SW1P 2HZ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['London', 'Greater London', 'SW1P 2HZ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732781', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.41620485,-0.04170230711502565&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5155879,0.096982&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5126553,-0.3051952&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5638ff9660b2753ece75b9f4', 'name': "Flava's Fine Indian Cuisine", 'location': {'address': '1 Mattock Lane, Ealing, Ealing London W5 5BG', 'lat': 51.5112056, 'lng': -0.3088582000000315, 'labeledLatLngs': [{'label': 'display', 'lat': 51.5112056, 'lng': -0.3088582000000315}], 'distance': 300, 'postalCode': 'W5 5BG', 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['1 Mattock Lane, Ealing, Ealing London W5 5BG', 'W5 5BG', 'United Kingdom']}, 'categories': [], 'referralId': 'v-1620732781', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5004439,-0.1265398&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5b7aa96cf96b2c002c2aab72', 'name': 'Indian Street Food', 'location': {'lat': 51.49734481108781, 'lng': -0.13384871301835802, 'labeledLatLngs': [{'label': 'display', 'lat': 51.49734481108781, 'lng': -0.13384871301835802}], 'distance': 612, 'postalCode': 'SW1P 2HZ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['London', 'Greater London', 'SW1P 2HZ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732781', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4624325,-0.0101331&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f37bc38e4b0ea2d7e2e69b4', 'name': 'Caaviya - Indian', 'location': {'lat': 51.462266, 'lng': -0.008392, 'labeledLatLngs': [{'label': 'display', 'lat': 51.462266, 'lng': -0.008392}], 'distance': 122, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d118951735', 'name': 'Grocery Store', 'pluralName': 'Grocery Stores', 'shortName': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732781', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5423045,-0.1395604&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f63375fe4b02ac2c3d4cff1', 'name': 'Indian Food', 'location': {'address': 'Stables Market Food Court', 'crossStreet': 'Ground Floor', 'lat': 51.541542059541165, 'lng': -0.14507715715115987, 'labeledLatLngs': [{'label': 'display', 'lat': 51.541542059541165, 'lng': -0.14507715715115987}], 'distance': 391, 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['Stables Market Food Court (Ground Floor)', 'Camden', 'Greater London', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732781', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.1374759,1.2952722&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4416793,0.150488&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5001dddbe4b0eed3b7269759', 'name': 'Mahan Finest Indian Takeaway', 'location': {'address': '70 Summerhouse Drive', 'lat': 51.43818644191744, 'lng': 0.15390318974056258, 'labeledLatLngs': [{'label': 'display', 'lat': 51.43818644191744, 'lng': 0.15390318974056258}], 'distance': 455, 'postalCode': 'DA5 2EE', 'cc': 'GB', 'city': 'Kent', 'state': 'Kent', 'country': 'United Kingdom', 'formattedAddress': ['70 Summerhouse Drive', 'Kent', 'DA5 2EE', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732782', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5156177,-0.0919983&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4624325,-0.0101331&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f37bc38e4b0ea2d7e2e69b4', 'name': 'Caaviya - Indian', 'location': {'lat': 51.462266, 'lng': -0.008392, 'labeledLatLngs': [{'label': 'display', 'lat': 51.462266, 'lng': -0.008392}], 'distance': 122, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d118951735', 'name': 'Grocery Store', 'pluralName': 'Grocery Stores', 'shortName': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732782', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4820845,-0.0045417&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.1374759,1.2952722&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5423045,-0.1395604&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f63375fe4b02ac2c3d4cff1', 'name': 'Indian Food', 'location': {'address': 'Stables Market Food Court', 'crossStreet': 'Ground Floor', 'lat': 51.541542059541165, 'lng': -0.14507715715115987, 'labeledLatLngs': [{'label': 'display', 'lat': 51.541542059541165, 'lng': -0.14507715715115987}], 'distance': 391, 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['Stables Market Food Court (Ground Floor)', 'Camden', 'Greater London', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732782', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6014736,-0.1117815&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.1374759,1.2952722&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6014736,-0.1117815&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5639957,-0.27590641378489267&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5013012,-0.117287&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4624325,-0.0101331&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f37bc38e4b0ea2d7e2e69b4', 'name': 'Caaviya - Indian', 'location': {'lat': 51.462266, 'lng': -0.008392, 'labeledLatLngs': [{'label': 'display', 'lat': 51.462266, 'lng': -0.008392}], 'distance': 122, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d118951735', 'name': 'Grocery Store', 'pluralName': 'Grocery Stores', 'shortName': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4906674,-0.20126327820511103&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4b6d1b28f964a52016672ce3', 'name': 'Indian Express', 'location': {'address': '3 Charleville Road', 'lat': 51.48895918453358, 'lng': -0.20633697509765625, 'labeledLatLngs': [{'label': 'display', 'lat': 51.48895918453358, 'lng': -0.20633697509765625}], 'distance': 399, 'postalCode': 'W1 4 9', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['3 Charleville Road', 'London', 'Greater London', 'W1 4 9', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}, {'id': '5294f7d811d2f248ffa2baa1', 'name': 'Indian Seasonings', 'location': {'lat': 51.48609039462223, 'lng': -0.20276957235273702, 'labeledLatLngs': [{'label': 'display', 'lat': 51.48609039462223, 'lng': -0.20276957235273702}], 'distance': 520, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}, {'id': '51cf30bf498e2c23fed00261', 'name': 'Indian Express', 'location': {'address': '3 North End Parade', 'lat': 51.49302784342529, 'lng': -0.20823223710944824, 'labeledLatLngs': [{'label': 'display', 'lat': 51.49302784342529, 'lng': -0.20823223710944824}], 'distance': 549, 'postalCode': 'W14 0SJ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['3 North End Parade', 'London', 'Greater London', 'W14 0SJ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5639957,-0.27590641378489267&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732783', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5029222,-0.103458&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5423045,-0.1395604&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f63375fe4b02ac2c3d4cff1', 'name': 'Indian Food', 'location': {'address': 'Stables Market Food Court', 'crossStreet': 'Ground Floor', 'lat': 51.541542059541165, 'lng': -0.14507715715115987, 'labeledLatLngs': [{'label': 'display', 'lat': 51.541542059541165, 'lng': -0.14507715715115987}], 'distance': 391, 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['Stables Market Food Court (Ground Floor)', 'Camden', 'Greater London', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732784', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.59816935,-0.01783667461048707&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.52999955,0.02931796029382208&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4820845,-0.0045417&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.498480400000005,-0.1990432138025393&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732784', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732784', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5004439,-0.1265398&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5b7aa96cf96b2c002c2aab72', 'name': 'Indian Street Food', 'location': {'lat': 51.49734481108781, 'lng': -0.13384871301835802, 'labeledLatLngs': [{'label': 'display', 'lat': 51.49734481108781, 'lng': -0.13384871301835802}], 'distance': 612, 'postalCode': 'SW1P 2HZ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['London', 'Greater London', 'SW1P 2HZ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732784', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4624325,-0.0101331&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f37bc38e4b0ea2d7e2e69b4', 'name': 'Caaviya - Indian', 'location': {'lat': 51.462266, 'lng': -0.008392, 'labeledLatLngs': [{'label': 'display', 'lat': 51.462266, 'lng': -0.008392}], 'distance': 122, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d118951735', 'name': 'Grocery Store', 'pluralName': 'Grocery Stores', 'shortName': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732784', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.59816935,-0.01783667461048707&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.427811399999996,-0.18227010823527548&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5384287,-0.0999051&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.41086985,-0.18809708858824303&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.65309,-0.2002261&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5005b98ce4b063622977273f', 'name': 'Suruchi Indian', 'location': {'lat': 51.652971527467855, 'lng': -0.20000771843360965, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652971527467855, 'lng': -0.20000771843360965}], 'distance': 20, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}, {'id': '4c7ea2af1009a093ce0d454e', 'name': 'Shapla Indian Restaurant Barnet', 'location': {'address': 'High St', 'lat': 51.652833298892794, 'lng': -0.19966241320137793, 'labeledLatLngs': [{'label': 'display', 'lat': 51.652833298892794, 'lng': -0.19966241320137793}], 'distance': 48, 'postalCode': 'En5 5UW', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['High St', 'London', 'Greater London', 'En5 5UW', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.56362505,-0.22769454999999897&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4416793,0.150488&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5001dddbe4b0eed3b7269759', 'name': 'Mahan Finest Indian Takeaway', 'location': {'address': '70 Summerhouse Drive', 'lat': 51.43818644191744, 'lng': 0.15390318974056258, 'labeledLatLngs': [{'label': 'display', 'lat': 51.43818644191744, 'lng': 0.15390318974056258}], 'distance': 455, 'postalCode': 'DA5 2EE', 'cc': 'GB', 'city': 'Kent', 'state': 'Kent', 'country': 'United Kingdom', 'formattedAddress': ['70 Summerhouse Drive', 'Kent', 'DA5 2EE', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732785', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6014736,-0.1117815&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4028046,0.0148142&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5432402,-0.0493621&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4624325,-0.0101331&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f37bc38e4b0ea2d7e2e69b4', 'name': 'Caaviya - Indian', 'location': {'lat': 51.462266, 'lng': -0.008392, 'labeledLatLngs': [{'label': 'display', 'lat': 51.462266, 'lng': -0.008392}], 'distance': 122, 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d118951735', 'name': 'Grocery Store', 'pluralName': 'Grocery Stores', 'shortName': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732786', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5639957,-0.27590641378489267&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5029222,-0.103458&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5126553,-0.3051952&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5638ff9660b2753ece75b9f4', 'name': "Flava's Fine Indian Cuisine", 'location': {'address': '1 Mattock Lane, Ealing, Ealing London W5 5BG', 'lat': 51.5112056, 'lng': -0.3088582000000315, 'labeledLatLngs': [{'label': 'display', 'lat': 51.5112056, 'lng': -0.3088582000000315}], 'distance': 300, 'postalCode': 'W5 5BG', 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['1 Mattock Lane, Ealing, Ealing London W5 5BG', 'W5 5BG', 'United Kingdom']}, 'categories': [], 'referralId': 'v-1620732786', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.498480400000005,-0.1990432138025393&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4570271,-0.1932607&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5029222,-0.103458&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# ...
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.498480400000005,-0.1990432138025393&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5763203,0.0454097&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6014736,-0.1117815&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4570271,-0.1932607&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6520851,-0.0810175&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5423045,-0.1395604&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f63375fe4b02ac2c3d4cff1', 'name': 'Indian Food', 'location': {'address': 'Stables Market Food Court', 'crossStreet': 'Ground Floor', 'lat': 51.541542059541165, 'lng': -0.14507715715115987, 'labeledLatLngs': [{'label': 'display', 'lat': 51.541542059541165, 'lng': -0.14507715715115987}], 'distance': 391, 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['Stables Market Food Court (Ground Floor)', 'Camden', 'Greater London', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732796', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5432402,-0.0493621&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5013012,-0.117287&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5432402,-0.0493621&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5013012,-0.117287&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6014736,-0.1117815&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4437263,-0.0202235&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5029041,-0.10598456348964677&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.517568749999995,-0.1411598575972799&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4ae59bebf964a5200ca121e3', 'name': 'Indian YMCA', 'location': {'address': '41 Fitzroy Sq', 'crossStreet': 'Grafton Way', 'lat': 51.522601476801405, 'lng': -0.13891924106296882, 'labeledLatLngs': [{'label': 'display', 'lat': 51.522601476801405, 'lng': -0.13891924106296882}], 'distance': 581, 'postalCode': 'W1T 6AQ', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['41 Fitzroy Sq (Grafton Way)', 'London', 'Greater London', 'W1T 6AQ', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d1ee931735', 'name': 'Hostel', 'pluralName': 'Hostels', 'shortName': 'Hostel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732797', 'hasPerk': False}, {'id': '5a9721a7872f7d0c0e60cb66', 'name': 'Indian Singles UK', 'location': {'address': '207 Regent Street', 'lat': 51.51323852, 'lng': -0.14112422, 'labeledLatLngs': [{'label': 'display', 'lat': 51.51323852, 'lng': -0.14112422}], 'distance': 482, 'postalCode': 'W1B 3HH', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['207 Regent Street', 'London', 'Greater London', 'W1B 3HH', 'United Kingdom']}, 'categories': [{'id': '56aa371be4b08b9a8d573554', 'name': 'Entertainment Service', 'pluralName': 'Entertainment Services', 'shortName': 'Entertainment Service', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732797', 'hasPerk': False}, {'id': '5f23ae7fffd2c04a6efc0e27', 'name': 'Indian Visa Online - London Office', 'location': {'address': 'India House, Aldwych,', 'lat': 51.51979918312931, 'lng': -0.13419628143310547, 'labeledLatLngs': [{'label': 'display', 'lat': 51.51979918312931, 'lng': -0.13419628143310547}], 'distance': 542, 'postalCode': 'WC2B 4NA', 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['India House, Aldwych,', 'London', 'Greater London', 'WC2B 4NA', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d1f6931735', 'name': 'General Travel', 'pluralName': 'General Travel', 'shortName': 'Travel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732797', 'hasPerk': False}, {'id': '4b7aababf964a5206f362fe3', 'name': 'KK Private Indian Bar', 'location': {'address': 'Pinner Road', 'lat': 51.513619, 'lng': -0.144432, 'labeledLatLngs': [{'label': 'display', 'lat': 51.513619, 'lng': -0.144432}], 'distance': 494, 'cc': 'GB', 'city': 'Harrow', 'country': 'United Kingdom', 'formattedAddress': ['Pinner Road', 'Harrow', 'United Kingdom']}, 'categories': [], 'referralId': 'v-1620732797', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4570271,-0.1932607&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.1374759,1.2952722&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5383536,-0.123155&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5013012,-0.117287&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.3713049,-0.101957&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.59816935,-0.01783667461048707&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.52999955,0.02931796029382208&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5013012,-0.117287&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5029222,-0.103458&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5763203,0.0454097&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.498480400000005,-0.1990432138025393&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5126553,-0.3051952&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5638ff9660b2753ece75b9f4', 'name': "Flava's Fine Indian Cuisine", 'location': {'address': '1 Mattock Lane, Ealing, Ealing London W5 5BG', 'lat': 51.5112056, 'lng': -0.3088582000000315, 'labeledLatLngs': [{'label': 'display', 'lat': 51.5112056, 'lng': -0.3088582000000315}], 'distance': 300, 'postalCode': 'W5 5BG', 'cc': 'GB', 'country': 'United Kingdom', 'formattedAddress': ['1 Mattock Lane, Ealing, Ealing London W5 5BG', 'W5 5BG', 'United Kingdom']}, 'categories': [], 'referralId': 'v-1620732798', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.52999955,0.02931796029382208&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5423045,-0.1395604&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f63375fe4b02ac2c3d4cff1', 'name': 'Indian Food', 'location': {'address': 'Stables Market Food Court', 'crossStreet': 'Ground Floor', 'lat': 51.541542059541165, 'lng': -0.14507715715115987, 'labeledLatLngs': [{'label': 'display', 'lat': 51.541542059541165, 'lng': -0.14507715715115987}], 'distance': 391, 'cc': 'GB', 'city': 'London', 'state': 'Greater London', 'country': 'United Kingdom', 'formattedAddress': ['Stables Market Food Court (Ground Floor)', 'Camden', 'Greater London', 'United Kingdom']}, 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732798', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.4920377,-0.2236401&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5013012,-0.117287&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.41086985,-0.18809708858824303&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.5763203,0.0454097&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=51.6009264,0.0141797&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
# printing dataframe containing details of Indian restaurant present in London
display(london_restaurant_df)
# Out:
#                           id  ... location.crossStreet
# 0   51cf30bf498e2c23fed00261  ...                  NaN
# 1   5b7aa96cf96b2c002c2aab72  ...                  NaN
# 2   4ce83bacf3bda1437526b8e4  ...                  NaN
# 3   4ce83bacf3bda1437526b8e4  ...                  NaN
# 4   5b7aa96cf96b2c002c2aab72  ...                  NaN
# ..                       ...  ...                  ...
# 68  5a9721a7872f7d0c0e60cb66  ...                  NaN
# 69  5f23ae7fffd2c04a6efc0e27  ...                  NaN
# 70  4b7aababf964a5206f362fe3  ...                  NaN
# 71  5638ff9660b2753ece75b9f4  ...                  NaN
# 72  4f63375fe4b02ac2c3d4cff1  ...         Ground Floor
#
# [73 rows x 17 columns]

# %%
# dropping unnecessary column
london_restaurant_df = london_restaurant_df.drop(['id', 'categories', 'referralId', 'hasPerk', 'location.labeledLatLngs', 'location.formattedAddress'], axis=1)
display(london_restaurant_df)
# Out:
#                                   name  ... location.crossStreet
# 0                       Indian Express  ...                  NaN
# 1                   Indian Street Food  ...                  NaN
# 2                          Blue Ginger  ...                  NaN
# 3                          Blue Ginger  ...                  NaN
# 4                   Indian Street Food  ...                  NaN
# ..                                 ...  ...                  ...
# 68                   Indian Singles UK  ...                  NaN
# 69  Indian Visa Online - London Office  ...                  NaN
# 70               KK Private Indian Bar  ...                  NaN
# 71         Flava's Fine Indian Cuisine  ...                  NaN
# 72                         Indian Food  ...         Ground Floor
#
# [73 rows x 11 columns]

# %% [markdown]
# **Visualization of all the Indian restaurant located in London**

# %%
# visualizing all the Indian restaurant in London neighborhoods from the above data frame using folium
# Indian Restaurant London map
map_rest_london = folium.Map(location=get_location('London, England'),zoom_start=10)

# adding marker to map
for lat,lng, rest_name in zip(london_restaurant_df['location.lat'],london_restaurant_df['location.lng'],london_restaurant_df['name']):
    label = '{}'.format(rest_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_rest_london)
map_rest_london
# Out:
# Latitude - 51.5073219, Longitude - -0.1276474
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_dea539c3ad3c4c37980ab592499a1ba5%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dea539c3ad3c4c37980ab592499a1ba5%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_dea539c3ad3c4c37980ab592499a1ba5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_dea539c3ad3c4c37980ab592499a1ba5%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_35c1d31720604710be5be51cd995a082%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# Clustering all the Indian restaurant located in London on the basis of there geographical location
#
# **Algorithm used - *KMeans***

# %%
# using K-Means clustering algorithm for the clustering of the Indian restaurant in London neighborhoods

k=5 # number of cluster

london_cluster_data = london_restaurant_df[:][['location.lat', 'location.lng']] # considering only numerical data
kmeans = KMeans(n_clusters = k,random_state=0).fit(london_cluster_data)
kmeans.labels_
london_restaurant_df.insert(0, 'Cluster Labels', kmeans.labels_)
display(london_restaurant_df)
# Out:
#     Cluster Labels  ... location.crossStreet
# 0                2  ...                  NaN
# 1                2  ...                  NaN
# 2                0  ...                  NaN
# 3                0  ...                  NaN
# 4                2  ...                  NaN
# ..             ...  ...                  ...
# 68               2  ...                  NaN
# 69               2  ...                  NaN
# 70               2  ...                  NaN
# 71               3  ...                  NaN
# 72               2  ...         Ground Floor
#
# [73 rows x 12 columns]

# %% [markdown]
# ***Visualization of all the Indian restaurant located in London divided in different clusters***

# %%
# visualizing all the 5 Indian restaurant neighborhoods cluster from the above data frame using folium
# London map
map_london_clusters = folium.Map(location=get_location('London, England'),zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# adding markers to the map
markers_colors = []
for lat, lon, rest_name, cluster in zip(london_restaurant_df['location.lat'],london_restaurant_df['location.lng'],london_restaurant_df['name'], london_restaurant_df['Cluster Labels']):
    label = folium.Popup(' Cluster - ' + str(cluster) + ', '+ rest_name, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_london_clusters)
map_london_clusters
# Out:
# Latitude - 51.5073219, Longitude - -0.1276474
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_afdfd3afd3d74b6fb4fa098ab3162e9d%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_afdfd3afd3d74b6fb4fa098ab3162e9d%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_afdfd3afd3d74b6fb4fa098ab3162e9d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_afdfd3afd3d74b6fb4fa098ab3162e9d%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_104fe2e6e743471f9f9f52031ab86261%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# let's find Indian food restaurant in ***New York*** and its borough through Foursquare API
#
# **Method name** - get_restaurant_nyc
#
# **Purpose** - It helps in listing all the Indian restaurant in New York
#
# **Input** - Dataframe which contain latitude and longitude details, query, radius, client_id, client_secret, access_token, version, limit
#
# **Response** - Restaurant details in JSON format

# %%
def get_restaurant_nyc(row, query, radius, client_id, client_secret, access_token, version, limit):
    latitude = row[2]
    longitude = row[3]
    url = f'https://api.foursquare.com/v2/venues/search?client_id={client_id}&client_secret={client_secret}&ll={latitude},{longitude}&oauth_token={access_token}&v={version}&query={query}&radius={radius}&limit={limit}'
    print(f'Final URL - {url}')
    resp = api_request(url)
    if resp['meta']['code'] == 200:
        print(resp['response'])
        # assign relevant part of JSON to venues
        venues = resp['response']['venues']
        return venues
    else:
        print(resp)

search_query = 'Indian'
radius = 500
print(f'query - {search_query}')
nyc_restaurant_series = nyc_data_df.apply(get_restaurant_nyc, args=(search_query, radius, CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN, VERSION, LIMIT), axis=1)
nyc_restaurant_series_updated = []
for x in nyc_restaurant_series:
    if len(x) > 0:
        nyc_restaurant_series_updated.extend(x)
nyc_restaurant_df = json_normalize(nyc_restaurant_series_updated)
# Out:
# query - Indian
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=40.8466508,-73.8785937&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=40.6501038,-73.9495823&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '4f19c785e4b0c9f57df2cbaf', 'name': 'West Indian Ave.', 'location': {'lat': 40.64673565381504, 'lng': -73.94871135351131, 'labeledLatLngs': [{'label': 'display', 'lat': 40.64673565381504, 'lng': -73.94871135351131}], 'distance': 382, 'postalCode': '11226', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['Brooklyn, NY 11226', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d1f9931735', 'name': 'Road', 'pluralName': 'Roads', 'shortName': 'Road', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732800', 'hasPerk': False}, {'id': '4f32549519836c91c7cd23e2', 'name': 'C B Finger Licking Jamaican and West Indian Restaurant', 'location': {'address': '1617 Nostrand Ave', 'lat': 40.64662170410156, 'lng': -73.94880676269531, 'labeledLatLngs': [{'label': 'entrance', 'lat': 40.646603, 'lng': -73.94898}, {'label': 'display', 'lat': 40.64662170410156, 'lng': -73.94880676269531}], 'distance': 393, 'postalCode': '11226', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1617 Nostrand Ave', 'Brooklyn, NY 11226', 'United States']}, 'categories': [{'id': '4d4b7105d754a06374d81259', 'name': 'Food', 'pluralName': 'Food', 'shortName': 'Food', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732800', 'hasPerk': False}, {'id': '4cdc6246c409b60ccf30da1a', 'name': "Lisa's Pub, Indian Head", 'location': {'lat': 40.652583, 'lng': -73.95466, 'labeledLatLngs': [{'label': 'display', 'lat': 40.652583, 'lng': -73.95466}], 'distance': 509, 'postalCode': '11226', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['Brooklyn, NY 11226', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d11b941735', 'name': 'Pub', 'pluralName': 'Pubs', 'shortName': 'Pub', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732800', 'hasPerk': False}, {'id': '4a611b29f964a520dec11fe3', 'name': "Nio's Trinidad Roti Shop", 'location': {'address': '2702 Church Ave', 'crossStreet': 'at Rogers Ave.', 'lat': 40.65063843199367, 'lng': -73.95233805638496, 'labeledLatLngs': [{'label': 'display', 'lat': 40.65063843199367, 'lng': -73.95233805638496}, {'label': 'entrance', 'lat': 40.650569, 'lng': -73.952251}], 'distance': 240, 'postalCode': '11226', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2702 Church Ave (at Rogers Ave.)', 'Brooklyn, NY 11226', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d144941735', 'name': 'Caribbean Restaurant', 'pluralName': 'Caribbean Restaurants', 'shortName': 'Caribbean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732800', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=40.7896239,-73.9598939&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': [{'id': '5b17c9f935d3fc002c2c09db', 'name': 'Indian Egg Donors DGA, Inc.', 'location': {'address': '1148 5th Ave', 'crossStreet': 'Suite 1B', 'lat': 40.78746795654297, 'lng': -73.9554443359375, 'labeledLatLngs': [{'label': 'display', 'lat': 40.78746795654297, 'lng': -73.9554443359375}], 'distance': 445, 'postalCode': '10128', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1148 5th Ave (Suite 1B)', 'New York, NY 10128', 'United States']}, 'categories': [{'id': '54541900498ea6ccd0202697', 'name': 'Health & Beauty Service', 'pluralName': 'Health & Beauty Services', 'shortName': 'Health & Beauty', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1620732800', 'hasPerk': False}]}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=40.7498243,-73.7976337&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# Final URL - https://api.foursquare.com/v2/venues/search?client_id=QUOSLG3QT4KFSFBZJ23JP1Z2Z30Y0NZMEUWI3FI05FRGXMMY&client_secret=QCEHGCY0EGU14T33S3PVOIJKHIF3N4PI150ZIDOTIEL2RL21&ll=40.5834557,-74.1496048&oauth_token=2A0SDC1GKCMH2WKNIFOKZT5WJJNZSQZWVD2M2NUQ2IPGA2Q2&v=20180604&query=Indian&radius=500&limit=30
# {'venues': []}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
# printing New York Indian restaurant detail in a dataframe
display(nyc_restaurant_df)
# Out:
#                          id  ... location.crossStreet
# 0  4f19c785e4b0c9f57df2cbaf  ...                  NaN
# 1  4f32549519836c91c7cd23e2  ...                  NaN
# 2  4cdc6246c409b60ccf30da1a  ...                  NaN
# 3  4a611b29f964a520dec11fe3  ...       at Rogers Ave.
# 4  5b17c9f935d3fc002c2c09db  ...             Suite 1B
#
# [5 rows x 17 columns]

# %%
# dropping unnecessary column from dataframe
nyc_restaurant_df = nyc_restaurant_df.drop(['id', 'categories', 'referralId', 'hasPerk', 'location.labeledLatLngs', 'location.formattedAddress'], axis=1)
display(nyc_restaurant_df)
# Out:
#                                                 name  ...  location.crossStreet
# 0                                   West Indian Ave.  ...                   NaN
# 1  C B Finger Licking Jamaican and West Indian Re...  ...                   NaN
# 2                            Lisa's Pub, Indian Head  ...                   NaN
# 3                           Nio's Trinidad Roti Shop  ...        at Rogers Ave.
# 4                        Indian Egg Donors DGA, Inc.  ...              Suite 1B
#
# [5 rows x 11 columns]

# %% [markdown]
# **Visualization of all the Indian restaurant located in New York**

# %%
# visualizing all the Indian restaurant in New York neighborhoods from the above data frame using folium
# Indian Restaurant New York map
map_rest_nyc = folium.Map(location=get_location('New York, USA'),zoom_start=10)

# adding marker to map
for lat,lng, rest_name in zip(nyc_restaurant_df['location.lat'],nyc_restaurant_df['location.lng'],nyc_restaurant_df['name']):
    label = '{}'.format(rest_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='red',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_rest_nyc)
map_rest_nyc
# Out:
# Latitude - 40.7127281, Longitude - -74.0060152
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_aee1fd5ce3484be08478c9da29078d64%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_aee1fd5ce3484be08478c9da29078d64%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_aee1fd5ce3484be08478c9da29078d64%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_aee1fd5ce3484be08478c9da29078d64%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_a3da5f3da56b49509bcdf15fa010dc50%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# Clustering all the Indian restaurant located in New York on the basis of there geographical location
#
# **Algorithm used - *KMeans***

# %%
# using K-Means clustering algorithm for the clustering of the Indian restaurant in New York neighborhoods
k=3

nyc_cluster_data = nyc_restaurant_df[:][['location.lat', 'location.lng']]
kmeans = KMeans(n_clusters = k,random_state=0).fit(nyc_cluster_data)
kmeans.labels_
nyc_restaurant_df.insert(0, 'Cluster Labels', kmeans.labels_)
display(nyc_restaurant_df)
# Out:
#    Cluster Labels  ... location.crossStreet
# 0               1  ...                  NaN
# 1               1  ...                  NaN
# 2               2  ...                  NaN
# 3               2  ...       at Rogers Ave.
# 4               0  ...             Suite 1B
#
# [5 rows x 12 columns]

# %% [markdown]
# ***Visualization of all the Indian restaurant located in New York divided in different clusters***

# %%
# visualizing all the 5 Indian restaurant neighborhoods cluster from the above data frame using folium
# New York map
map_nyc_clusters = folium.Map(location=get_location('New York, USA'),zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# adding markers to the map
markers_colors = []
for lat, lon, rest_name, cluster in zip(nyc_restaurant_df['location.lat'],nyc_restaurant_df['location.lng'],nyc_restaurant_df['name'], nyc_restaurant_df['Cluster Labels']):
    label = folium.Popup(' Cluster - ' + str(cluster) + ', '+ rest_name, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_nyc_clusters)
map_nyc_clusters
# Out:
# Latitude - 40.7127281, Longitude - -74.0060152
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_5f0d8845cea947fdb372466ba3de6bfb%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5f0d8845cea947fdb372466ba3de6bfb%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_5f0d8845cea947fdb372466ba3de6bfb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_5f0d8845cea947fdb372466ba3de6bfb%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_c938249336584d9fb25f5eb420f7197d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# # **Results and Discussion**
# *   From the above analysis, we can see that London has more number of Indian restaurant than New York.
# *   After implementing KMeans clustering algorithm on both the cities restuarant data it can be seen that **Central London** borough area of London has highest number of Indian restaurant among all borough of London.
#
# **Analysis Details-**
#
#
# *   Collected city borough data from wikipedia for both the city London and New York.
# *   Using geocoder python library found geographical location (latitude and longitude) of each borough of both the cities.
# *   Using folium python library to plot map of both London and New York borough location.
# *   Using Foursquare API collected all the Indian restaurant details of each borough of both the cities.
# *   Using KMeans clustering algorithm clustered all the nearest Indian restaurant in both the cities.
# *   Using folium plotted individual map which contain all the cluster of New York and London.

# %% [markdown]
# # **Conclusion**
# The purpose of this project was to explore the cities of London and New York and see how attractive it is to potential tourists and residents. We explored both the cities based on their borough and find number of Indian food restaurant located their, finally concluding with clustering similar restaurant based on there location together.
#
# We could see that London has a wide variety of experiences to offer in term of Indian restaurant which is unique in it's own way than New York. The cultural diversity in food is quite evident which also gives the feeling of a sense of inclusion to Indian tourists and residents.
#
# Both New York and London seem to offer Indian restaurant but in numbers London win the race. **Overall, my suggesstion would be to go London if you are looking for good Indian food because it has around 73 Indian restaurant and especially Central London because it has more number of Indian resturant then other borough.**

# %% [markdown]
# # **Click on Open in Colab button present at top of notebook to see the Folium Map**
